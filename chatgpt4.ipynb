# %%
import pandas as pd

chatgpt4= pd.read_csv('realChatGPT4.csv')
chatgpt4
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 1    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 2    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    60.0  90.0  1.015  3.0  0.0     NaN       NaN  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 591  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 592  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 593  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 594  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 595  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
chatgpt4 = chatgpt4.drop(columns=['id'])
print(chatgpt4.shape)
# Out:
# (596, 25)

# %%
print(chatgpt4.isna().sum())
print("---------------------------------")
print(chatgpt4.duplicated().sum())
print(chatgpt4.shape)
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               131
# pc                 27
# pcc                 9
# ba                  9
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                22
# wc                 68
# rc                 77
# htn                 6
# dm                  6
# cad                 6
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64
# ---------------------------------
# 384
# (596, 25)

# %%
chatgpt4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             596 non-null    float64
#  1   bp              596 non-null    float64
#  2   sg              596 non-null    float64
#  3   al              596 non-null    float64
#  4   su              596 non-null    float64
#  5   rbc             465 non-null    object
#  6   pc              569 non-null    object
#  7   pcc             587 non-null    object
#  8   ba              587 non-null    object
#  9   bgr             596 non-null    float64
#  10  bu              596 non-null    float64
#  11  sc              596 non-null    float64
#  12  sod             596 non-null    float64
#  13  pot             596 non-null    float64
#  14  hemo            596 non-null    float64
#  15  pcv             574 non-null    float64
#  16  wc              528 non-null    float64
# ...

# %%
chatgpt4.isna().sum()
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               131
# pc                 27
# pcc                 9
# ba                  9
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                22
# wc                 68
# rc                 77
# htn                 6
# dm                  6
# cad                 6
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
chatgpt4['pcv'] = chatgpt4['pcv'].astype(str)
chatgpt4['wc'] = chatgpt4['wc'].astype(str)
chatgpt4['rc'] = chatgpt4['rc'].astype(str)

chatgpt4['pcv'] = chatgpt4['pcv'].str.replace('\t', '').str.replace('?', '')
chatgpt4['wc'] = chatgpt4['wc'].str.replace('\t', '').str.replace('?', '')
chatgpt4['rc'] = chatgpt4['rc'].str.replace('\t', '').str.replace('?', '')

chatgpt4['pcv'] = pd.to_numeric(chatgpt4['pcv'], errors='coerce')
chatgpt4['wc'] = pd.to_numeric(chatgpt4['wc'], errors='coerce')
chatgpt4['rc'] = pd.to_numeric(chatgpt4['rc'], errors='coerce')

print(chatgpt4[['pcv', 'wc', 'rc']].dtypes)

print(chatgpt4['rc'].values)
print(chatgpt4['wc'].values)
print(chatgpt4['pcv'].values)
# Out:
# pcv    float64
# wc     float64
# rc     float64
# dtype: object
# [3.9 3.9 3.9 3.9 4.4 nan nan nan 3.7 3.7 3.7 3.8 3.8 3.8 3.4 3.4 2.8 nan
#  nan 3.2 3.2 3.2 3.4 3.4 3.4 3.7 3.7 3.7 4.  4.  4.1 4.1 4.  4.  4.  4.
#  4.  4.  nan nan 4.2 4.2 4.2 4.5 4.5 4.5 4.5 3.1 3.1 3.1 3.1 3.1 nan nan
#  4.7 4.7 3.5 3.5 3.5 3.5 3.5 nan nan 4.3 4.3 4.3 3.8 3.8 3.8 nan nan 5.2
#  5.2 3.2 3.2 3.4 3.4 3.4 3.4 3.4 3.7 3.8 3.8 3.8 3.8 2.1 2.1 2.1 4.2 4.2
#  4.2 5.6 5.6 5.6 3.6 3.6 3.2 3.2 3.2 3.2 3.2 3.2 3.9 3.9 3.9 3.9 3.9 3.9
#  3.9 3.9 nan nan nan nan 5.2 5.2 5.2 5.2 5.2 5.2 4.4 4.2 4.7 4.7 3.9 3.9
#  3.9 3.9 nan nan nan nan nan nan 4.5 4.3 4.3 4.3 4.3 2.9 2.9 2.9 2.9 2.9
#  2.9 nan nan nan nan 2.7 nan nan nan nan nan nan 4.1 3.  3.  3.  nan nan
#  nan nan nan 2.9 2.9 3.  3.  3.9 3.9 3.9 nan nan nan 4.3 3.2 3.2 3.2 3.2
#  4.4 3.1 3.1 3.1 4.9 4.9 nan nan 3.9 nan nan nan nan 3.7 nan nan nan nan
#  3.6 3.6 3.6 3.6 3.4 3.4 4.8 4.8 nan nan nan nan nan nan nan nan nan nan
# ...

# %%
import pandas as pd
from scipy.stats import mode

# Function to replace NaN with mean in numerical features and mode in categorical features
def replace_nan_with_mean_mode(df):
    for column in df.columns:
        if df[column].dtype in ['int64', 'float64']:
            mean_value = round(df[column].mean(),2)
            df[column] = df[column].fillna(mean_value)
        else:
            mode_value = df[column].mode()[0]
            df[column] = df[column].fillna(mode_value)
    return df

# Example usage with a sample DataFrame
# Assuming chatgpt3_5 is already defined
chatgpt4 = replace_nan_with_mean_mode(chatgpt4)



# Check the DataFrame
chatgpt4.rc.unique()
# Out:
# array([3.9 , 4.4 , 4.79, 3.7 , 3.8 , 3.4 , 2.8 , 3.2 , 4.  , 4.1 , 4.2 ,
#        4.5 , 3.1 , 4.7 , 3.5 , 4.3 , 5.2 , 2.1 , 5.6 , 3.6 , 2.9 , 2.7 ,
#        3.  , 4.9 , 4.8 , 4.6 , 3.3 , 6.1 , 2.5 , 5.  , 6.2 , 6.3 , 5.1 ,
#        5.8 , 5.5 , 5.3 , 5.4 , 6.4 , 6.  , 5.9 , 5.7 , 6.5 ])

# %%
import seaborn as sns
import pandas as pd

# Assuming chatgpt3_5 is your DataFrame
# Replace 'classification' with the actual name of your classification column
chatgpt4['classification'] = chatgpt4['classification'].replace({'ckd\t': 'ckd'})


sns.histplot(chatgpt4.classification)
chatgpt4.classification.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         ckd
# 1         ckd
# 2         ckd
# 3         ckd
# 4         ckd
#         ...
# 591    notckd
# 592    notckd
# 593    notckd
# 594    notckd
# 595    notckd
# Name: classification, Length: 596, dtype: object>

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
categorical_columns = chatgpt4.select_dtypes(include=['object']).columns
one_hot_encoded_chat4 = pd.get_dummies(chatgpt4, columns=categorical_columns)

one_hot_encoded_chat4
# Out:
#       age    bp     sg   al   su    bgr    bu   sc    sod  pot  ...  cad_no  \
# 0    48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...    True
# 1    48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...    True
# 2    48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...    True
# 3    48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...    True
# 4    60.0  90.0  1.015  3.0  0.0   74.0  25.0  1.1  142.0  3.2  ...    True
# ..    ...   ...    ...  ...  ...    ...   ...  ...    ...  ...  ...     ...
# 591  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  ...    True
# 592  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  ...    True
# 593  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  ...    True
# 594  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  ...    True
# 595  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  ...    True
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

ordinal_encoded_chat4 = chatgpt4.copy()

label_encoders = {}
for column in ordinal_encoded_chat4.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    ordinal_encoded_chat4[column] = label_encoders[column].fit_transform(ordinal_encoded_chat4[column])
ordinal_encoded_chat4
# Out:
#       age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv      wc  \
# 0    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 1    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 2    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 3    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 4    60.0  90.0  1.015  3.0  0.0    1   1    0   0   74.0  ...  39.0  7800.0
# ..    ...   ...    ...  ...  ...  ...  ..  ...  ..    ...  ...   ...     ...
# 591  42.0  70.0  1.025  0.0  0.0    1   1    0   0   75.0  ...  54.0  7800.0
# 592  12.0  80.0  1.020  0.0  0.0    1   1    0   0  100.0  ...  49.0  6600.0
# 593  12.0  80.0  1.020  0.0  0.0    1   1    0   0  100.0  ...  49.0  6600.0
# 594  17.0  60.0  1.025  0.0  0.0    1   1    0   0  114.0  ...  51.0  7200.0
# 595  17.0  60.0  1.025  0.0  0.0    1   1    0   0  114.0  ...  51.0  7200.0
#
# ...

# %%
ordinal_encoded_chat4.classification.unique()
ordinal_encoded_chat4.drop_duplicates
ordinal_encoded_chat4.to_csv("cleaned_chatgpt4.csv")
ordinal_encoded_chat4
# Out:
#       age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv      wc  \
# 0    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 1    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 2    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 3    48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 4    60.0  90.0  1.015  3.0  0.0    1   1    0   0   74.0  ...  39.0  7800.0
# ..    ...   ...    ...  ...  ...  ...  ..  ...  ..    ...  ...   ...     ...
# 591  42.0  70.0  1.025  0.0  0.0    1   1    0   0   75.0  ...  54.0  7800.0
# 592  12.0  80.0  1.020  0.0  0.0    1   1    0   0  100.0  ...  49.0  6600.0
# 593  12.0  80.0  1.020  0.0  0.0    1   1    0   0  100.0  ...  49.0  6600.0
# 594  17.0  60.0  1.025  0.0  0.0    1   1    0   0  114.0  ...  51.0  7200.0
# 595  17.0  60.0  1.025  0.0  0.0    1   1    0   0  114.0  ...  51.0  7200.0
#
# ...

# %%
x=ordinal_encoded_chat4.iloc[:,:-1].values
y=ordinal_encoded_chat4.iloc[:,-1].values
x
# Out:
# array([[48.   , 70.   ,  1.005, ...,  1.   ,  1.   ,  1.   ],
#        [48.   , 70.   ,  1.005, ...,  1.   ,  1.   ,  1.   ],
#        [48.   , 70.   ,  1.005, ...,  1.   ,  1.   ,  1.   ],
#        ...,
#        [12.   , 80.   ,  1.02 , ...,  0.   ,  0.   ,  0.   ],
#        [17.   , 60.   ,  1.025, ...,  0.   ,  0.   ,  0.   ],
#        [17.   , 60.   ,  1.025, ...,  0.   ,  0.   ,  0.   ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score,accuracy_score, f1_score ,confusion_matrix
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 42)

# %%
logreg_model = LogisticRegression(random_state=42)
logreg_model.fit(X_train, y_train)
y_pred_logreg = logreg_model.predict(X_test)
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
precision_logreg = precision_score(y_test, y_pred_logreg)
recall_logreg = recall_score(y_test, y_pred_logreg)
f1_logreg = f1_score(y_test, y_pred_logreg)
print("Logistic Regression Model Accuracy:", accuracy_logreg)
print("Logistic Regression Precision:", precision_logreg)
print("Logistic Regression Recall:", recall_logreg)
print("Logistic Regression F1 Score:", f1_logreg)

logreg_cm = confusion_matrix(y_test, y_pred_logreg)
plt.figure(figsize=(5, 4))
sns.heatmap(logreg_cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Logistic Regression Model Accuracy: 0.9246231155778895
# Logistic Regression Precision: 0.9122807017543859
# Logistic Regression Recall: 0.9541284403669725
# Logistic Regression F1 Score: 0.9327354260089686
# c:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def knn_accuracy(range_start, range_end, X_train, X_test, y_train, y_test):
    max_accuracy = 0
    best_n_neighbors = 0
    best_cm = None
    best_precision = 0
    best_recall = 0
    best_f1 = 0

    for i in range(range_start, range_end + 1):
        if i % 2 != 0:
            knn_model = KNeighborsClassifier(n_neighbors=i)
            knn_model.fit(X_train, y_train)
            y_pred_knn = knn_model.predict(X_test)
            accuracy_knn = accuracy_score(y_test, y_pred_knn)
            precision_knn = precision_score(y_test, y_pred_knn, average='macro', zero_division=0)
            recall_knn = recall_score(y_test, y_pred_knn, average='macro', zero_division=0)
            f1_knn = f1_score(y_test, y_pred_knn, average='macro', zero_division=0)
            if accuracy_knn > max_accuracy:
                max_accuracy = accuracy_knn
                best_n_neighbors = i
                best_cm = confusion_matrix(y_test, y_pred_knn)
                best_precision = precision_knn
                best_recall = recall_knn
                best_f1 = f1_knn

    print(f"Maximum Accuracy: {max_accuracy}, Best Number of Neighbors: {best_n_neighbors}")
    print(f"Precision: {best_precision} \nRecall: {best_recall} \nF1 Score: {best_f1}")

    plt.figure(figsize=(5, 4))
    sns.heatmap(best_cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix - k-NN')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    return max_accuracy, best_n_neighbors

# %%
max_accuracy, best_n_neighbors = knn_accuracy(3, 266, X_train, X_test, y_train, y_test)
# Out:
# Maximum Accuracy: 0.914572864321608, Best Number of Neighbors: 3
# Precision: 0.9288172043010753
# Recall: 0.9065239551478084
# F1 Score: 0.9120041617895696

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
knn_model = KNeighborsClassifier(3)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn, average='macro', zero_division=0)
recall_knn = recall_score(y_test, y_pred_knn, average='macro', zero_division=0)
f1_knn = f1_score(y_test, y_pred_knn, average='macro', zero_division=0)
print(f"Maximum Accuracy: {accuracy_knn}, Best Number of Neighbors: {best_n_neighbors}")
print(f"Precision: {precision_knn} \nRecall: {recall_knn} \nF1 Score: {f1_knn}")

con = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(5, 4))
sns.heatmap(con,annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - k-NN')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Maximum Accuracy: 0.914572864321608, Best Number of Neighbors: 3
# Precision: 0.9288172043010753
# Recall: 0.9065239551478084
# F1 Score: 0.9120041617895696

# %%
mlp_model = MLPClassifier(random_state=42)
mlp_model.fit(X_train, y_train)
y_pred_mlp = mlp_model.predict(X_test)
accuracy_mlp = accuracy_score(y_test, y_pred_mlp)
precision_mlp = precision_score(y_test, y_pred_mlp)
recall_mlp = recall_score(y_test, y_pred_mlp)
f1_mlp = f1_score(y_test, y_pred_mlp)
print("MLP Model Accuracy:", accuracy_mlp)
print("MLP Precision:", precision_mlp)
print("MLP Recall:", recall_mlp)
print("MLP F1 Score:", f1_mlp)
mlp_cm = confusion_matrix(y_test, y_pred_mlp)
plt.figure(figsize=(5, 4))
sns.heatmap(mlp_cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - MLP')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# MLP Model Accuracy: 0.8190954773869347
# MLP Precision: 0.8762886597938144
# MLP Recall: 0.7798165137614679
# MLP F1 Score: 0.8252427184466019

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
def create_mlp_model(input_dim):
    model = Sequential([
        Dense(64, activation='relu', input_dim=input_dim),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    return model
mlp_model = create_mlp_model(input_dim=X_train.shape[1])
mlp_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
mlp_model.fit(X_train, y_train, epochs=3, batch_size=32, validation_split=0.2)
loss, accuracy = mlp_model.evaluate(X_test, y_test)
print("MLP Model Accuracy:", accuracy)
cm = confusion_matrix(y_test, y_pred_mlp)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - MLP')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Epoch 1/3
# c:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4264 - loss: 212.0935 - val_accuracy: 0.5625 - val_loss: 58.7391
# Epoch 2/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4139 - loss: 51.9145 - val_accuracy: 0.5625 - val_loss: 51.6208
# Epoch 3/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5208 - loss: 39.0336 - val_accuracy: 0.4125 - val_loss: 5.1480
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4614 - loss: 5.2455
# MLP Model Accuracy: 0.44723618030548096

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np

# Step 1: Prepare predictions from base models on the validation set
predictions_val = []

# Append predictions from each base model
predictions_val.append(logreg_model.predict(X_train))
predictions_val.append(mlp_model.predict(X_train))
predictions_val.append(knn_model.predict(X_train))

# Stack predictions horizontally
meta_X_val = np.column_stack(predictions_val)

# Step 2: Train the meta-model (Logistic Regression)
meta_model = LogisticRegression(random_state=42)
meta_model.fit(meta_X_val, y_train)

# Step 3: Make predictions with the stacked ensemble on the test set
predictions_test = []

# Append predictions from each base model on the test set
predictions_test.append(logreg_model.predict(X_test))
predictions_test.append(mlp_model.predict(X_test))
predictions_test.append(knn_model.predict(X_test))
# Stack predictions horizontally
meta_X_test = np.column_stack(predictions_test)

# Use the trained meta-model to make predictions on the test set
stacked_predictions_test = meta_model.predict(meta_X_test)

# Evaluate the performance of the stacked ensemble
accuracy_stacked = accuracy_score(y_test, stacked_predictions_test)
precision_stacked = precision_score(y_test, stacked_predictions_test)
recall_stacked = recall_score(y_test, stacked_predictions_test)
f1_stacked = f1_score(y_test, stacked_predictions_test)

print("Stacked Ensemble Model Accuracy:", accuracy_stacked)
print("Stacked Ensemble Precision:", precision_stacked)
print("Stacked Ensemble Recall:", recall_stacked)
print("Stacked Ensemble F1 Score:", f1_stacked)

# Calculate confusion matrix for the stacked ensemble
stacked_cm = confusion_matrix(y_test, stacked_predictions_test)

# Plot the confusion matrix
plt.figure(figsize=(5, 4))
sns.heatmap(stacked_cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Stacked Ensemble')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Stacked Ensemble Model Accuracy: 0.914572864321608
# Stacked Ensemble Precision: 0.8709677419354839
# Stacked Ensemble Recall: 0.9908256880733946
# Stacked Ensemble F1 Score: 0.927038626609442

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedKFold, LeaveOneOut,ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)
# Define a dictionary to store the models
models = {
    'Logistic Regression': LogisticRegression(max_iter=100),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Machine': SVC(probability=True),
    'Multi-Layer Perceptron': MLPClassifier(max_iter=100)
}

# Initialize Leave-One-Out cross-validator
cv_methods = {
    'Stratified K-Fold': StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    'Leave-One-Out': LeaveOneOut(),
    'Shuffle-Split': ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
}
# Perform cross-validation for each model and each cross-validation method
results = {}
for model_name, model in models.items():
    print(f"Model: {model_name}")
    for cv_name, cv_method in cv_methods.items():
        # Lists to store evaluation metrics
        precision_scores = []
        recall_scores = []
        f1_scores = []
        accuracy_scores = []

        # Perform cross-validation
        for train_idx, test_idx in cv_method.split(x, y):
            X_train, X_test = x[train_idx], x[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Train the model
            model.fit(X_train, y_train)
            # Make predictions
            y_pred = model.predict(X_test)

            # Calculate evaluation metrics
            precision = precision_score(y_test, y_pred)
            recall = recall_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred)
            accuracy = accuracy_score(y_test, y_pred)

            # Append scores to lists
            precision_scores.append(precision)
            recall_scores.append(recall)
            f1_scores.append(f1)
            accuracy_scores.append(accuracy)

        # Store results
        results[(model_name, cv_name)] = {
            'Precision': np.mean(precision_scores),
            'Recall': np.mean(recall_scores),
            'F1-score': np.mean(f1_scores),
            'Accuracy': np.mean(accuracy_scores)
        }

# Create DataFrame for results
results_df = pd.DataFrame(results).T
print(results_df)
from sklearn.metrics import roc_auc_score

# Initialize dictionary to store AUC scores
auc_results = {}

# Perform cross-validation for each model and each cross-validation method
for model_name, model in models.items():
    print(f"Model: {model_name}")
    for cv_name, cv_method in cv_methods.items():
        # Initialize list to store AUC scores for this model and cross-validation method
        auc_scores = []

        # Perform cross-validation
        for train_idx, test_idx in cv_method.split(x, y):


            # Check if both classes are present in the test set
            if len(np.unique(y_test)) == 2:

                # Make predictions
                y_pred_proba = model.predict_proba(X_test)[:, 1]  # Probability of positive class

                # Calculate AUC score
                auc = roc_auc_score(y_test, y_pred_proba)
                auc_scores.append(auc)
            else:
                print(f"Skipping AUC calculation for {model_name} - {cv_name} due to only one class present in y_true.")

        # Store average AUC score for this model and cross-validation method
        auc_results[(model_name, cv_name)] = np.mean(auc_scores)

        # Print average AUC score
        print(f"CV Method: {cv_name}")
        print(f"Average AUC: {np.mean(auc_scores)}")

# Convert results to DataFrame
auc_results_df = pd.DataFrame.from_dict(auc_results, orient='index', columns=['AUC'])

# Display AUC scores
print(auc_results_df)
# Out:
# Model: Logistic Regression
# c:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
